# %%
import pandas as pd
import numpy as np

tf = pd.read_csv('train.csv')
kf = pd.read_csv('key.csv')
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4617600 entries, 0 to 4617599
# Data columns (total 4 columns):
# date         object
# store_nbr    int64
# item_nbr     int64
# units        int64
# dtypes: int64(3), object(1)

# %%
qf = tf[tf['units'] > 0]

# %%
qf = pd.merge(kf,qf)
qf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118696 entries, 0 to 118695
# Data columns (total 5 columns):
# store_nbr      118696 non-null int64
# station_nbr    118696 non-null int64
# date           118696 non-null object
# item_nbr       118696 non-null int64
# units          118696 non-null int64
# dtypes: int64(4), object(1)

# %%
qf.groupby('station_nbr').head(10)
# Out:
#         store_nbr  station_nbr        date  item_nbr  units
# 0               1            1  2012-01-01         9     29
# 1               1            1  2012-01-01        28      2
# 2               1            1  2012-01-01        51      1
# 3               1            1  2012-01-02         9     60
# 4               1            1  2012-01-02        28      5
# 5               1            1  2012-01-02        51      1
# 6               1            1  2012-01-03         9     15
# 7               1            1  2012-01-03        28      9
# 8               1            1  2012-01-04         9     20
# 9               1            1  2012-01-04        28      3
# 2877            2           14  2012-01-01         5    191
# 2878            2           14  2012-01-01        44    215
# 2879            2           14  2012-01-02         5    147
# 2880            2           14  2012-01-02        11      2
# 2881            2           14  2012-01-02        44    153
# ...
